# %% [markdown]
# ### 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %% [markdown]
# ### 範例
# 接下來的程式碼會示範如何定義一個簡單的 CNN model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 使用 colab 環境的同學請執行以下程式碼
# %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
import tensorflow as tf

print(tf.__version__)

# import os
# from google.colab import drive 
# drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
# %cd 'gdrive/My Drive'
# os.system("mkdir cupoy_cv_part4") # 可以自己改路徑
# %cd cupoy_cv_part4 # 可以自己改路徑
# Out:
# `%tensorflow_version` only switches the major version: 1.x or 2.x.
# You set: `1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2`. This will be interpreted as: `1.x`.
#
#
# TensorFlow 1.x selected.
# 1.15.2

# %%
# !unzip test.zip
# !unzip training.zip
# Out:
# Archive:  test.zip
#   inflating: test.csv
# Archive:  training.zip
#   inflating: training.csv

# %%
# 讀取資料集以及做前處理的函數
def load_data(dirname):
    # 讀取 csv 文件
    data = pd.read_csv(dirname)
    # 過濾有缺失值的 row
    data = data.dropna()

    # 將圖片像素值讀取為 numpy array 的形態
    data['Image'] = data['Image'].apply(lambda img: np.fromstring(img, sep=' ')).values 

    # 單獨把圖像 array 抽取出來
    imgs = np.vstack(data['Image'].values)/255
    # reshape 為 96 x 96
    imgs = imgs.reshape(data.shape[0], 96, 96)
    # 轉換為 float
    imgs = imgs.astype(np.float32)
    
    # 提取坐標的部分
    points = data[data.columns[:-1]].values

    # 轉換為 float
    points = points.astype(np.float32)

    # normalize 坐標值到 [-0.5, 0.5]
    points = points/96 - 0.5
    
    return imgs, points

# %%
# 讀取資料
imgs_train, points_train = load_data(dirname = 'training.csv')
print("圖像資料:", imgs_train.shape, "\n關鍵點資料:", points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# Out:
# Using TensorFlow backend.

# %%
# 回傳定義好的 model 的函數
def get_model():
    # 定義人臉關鍵點檢測網路
    model = Sequential()

    # 定義神經網路的輸入
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    # 最後輸出 30 維的向量，也就是 15 個關鍵點的值
    model.add(Dense(30))
    return model

# %%
model = get_model()
# 配置 loss funtion 和 optimizer
model.compile(loss='mean_squared_error', optimizer='adam')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
# 印出網路結構
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 1,424,286
# Trainable params: 1,424,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, History

# model checkpoint 
checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# training the model
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
# save the model weights
model.save_weights('weights.h5')
# save the model
model.save('model.h5')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3005: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Train on 1712 samples, validate on 428 samples
# Epoch 1/150
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 1712/1712 [==============================] - 15s 9ms/step - loss: 0.0073 - val_loss: 0.0022
#
# Epoch 00001: val_loss improved from inf to 0.00224, saving model to best_weights.h5
# Epoch 2/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0019 - val_loss: 0.0019
#
# Epoch 00002: val_loss improved from 0.00224 to 0.00195, saving model to best_weights.h5
# Epoch 3/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0014 - val_loss: 0.0019
#
# Epoch 00003: val_loss improved from 0.00195 to 0.00191, saving model to best_weights.h5
# Epoch 4/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0013 - val_loss: 0.0019
#
# Epoch 00004: val_loss improved from 0.00191 to 0.00189, saving model to best_weights.h5
# Epoch 5/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0012 - val_loss: 0.0018
#
# Epoch 00005: val_loss improved from 0.00189 to 0.00184, saving model to best_weights.h5
# Epoch 6/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0011 - val_loss: 0.0018
#
# Epoch 00006: val_loss improved from 0.00184 to 0.00179, saving model to best_weights.h5
# Epoch 7/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0010 - val_loss: 0.0019
#
# Epoch 00007: val_loss did not improve from 0.00179
# Epoch 8/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.3964e-04 - val_loss: 0.0017
#
# Epoch 00008: val_loss improved from 0.00179 to 0.00169, saving model to best_weights.h5
# Epoch 9/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 8.0546e-04 - val_loss: 0.0016
#
# Epoch 00009: val_loss improved from 0.00169 to 0.00164, saving model to best_weights.h5
# Epoch 10/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 7.1404e-04 - val_loss: 0.0014
#
# Epoch 00010: val_loss improved from 0.00164 to 0.00144, saving model to best_weights.h5
# Epoch 11/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 6.3054e-04 - val_loss: 0.0013
#
# Epoch 00011: val_loss improved from 0.00144 to 0.00128, saving model to best_weights.h5
# Epoch 12/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 5.6721e-04 - val_loss: 0.0012
#
# Epoch 00012: val_loss improved from 0.00128 to 0.00118, saving model to best_weights.h5
# Epoch 13/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 5.1054e-04 - val_loss: 0.0011
#
# Epoch 00013: val_loss improved from 0.00118 to 0.00110, saving model to best_weights.h5
# Epoch 14/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 5.0665e-04 - val_loss: 0.0010
#
# Epoch 00014: val_loss improved from 0.00110 to 0.00105, saving model to best_weights.h5
# Epoch 15/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 4.6409e-04 - val_loss: 9.9250e-04
#
# Epoch 00015: val_loss improved from 0.00105 to 0.00099, saving model to best_weights.h5
# Epoch 16/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 4.3241e-04 - val_loss: 9.6851e-04
#
# Epoch 00016: val_loss improved from 0.00099 to 0.00097, saving model to best_weights.h5
# Epoch 17/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.9961e-04 - val_loss: 9.8449e-04
#
# Epoch 00017: val_loss did not improve from 0.00097
# Epoch 18/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.9408e-04 - val_loss: 9.3130e-04
#
# Epoch 00018: val_loss improved from 0.00097 to 0.00093, saving model to best_weights.h5
# Epoch 19/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.7765e-04 - val_loss: 9.1098e-04
#
# Epoch 00019: val_loss improved from 0.00093 to 0.00091, saving model to best_weights.h5
# Epoch 20/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.6229e-04 - val_loss: 8.6049e-04
#
# Epoch 00020: val_loss improved from 0.00091 to 0.00086, saving model to best_weights.h5
# Epoch 21/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.6563e-04 - val_loss: 9.1697e-04
#
# Epoch 00021: val_loss did not improve from 0.00086
# Epoch 22/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.3614e-04 - val_loss: 8.6394e-04
#
# Epoch 00022: val_loss did not improve from 0.00086
# Epoch 23/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.2860e-04 - val_loss: 8.1540e-04
#
# Epoch 00023: val_loss improved from 0.00086 to 0.00082, saving model to best_weights.h5
# Epoch 24/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.2265e-04 - val_loss: 8.6640e-04
#
# Epoch 00024: val_loss did not improve from 0.00082
# Epoch 25/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.1028e-04 - val_loss: 8.2735e-04
#
# Epoch 00025: val_loss did not improve from 0.00082
# Epoch 26/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.0973e-04 - val_loss: 7.9673e-04
#
# Epoch 00026: val_loss improved from 0.00082 to 0.00080, saving model to best_weights.h5
# Epoch 27/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.9241e-04 - val_loss: 7.7405e-04
#
# Epoch 00027: val_loss improved from 0.00080 to 0.00077, saving model to best_weights.h5
# Epoch 28/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.8675e-04 - val_loss: 8.0299e-04
#
# Epoch 00028: val_loss did not improve from 0.00077
# Epoch 29/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.7953e-04 - val_loss: 7.9185e-04
#
# Epoch 00029: val_loss did not improve from 0.00077
# Epoch 30/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.7702e-04 - val_loss: 7.9663e-04
#
# Epoch 00030: val_loss did not improve from 0.00077
# Epoch 31/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.6768e-04 - val_loss: 8.1547e-04
#
# Epoch 00031: val_loss did not improve from 0.00077
# Epoch 32/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.6853e-04 - val_loss: 7.7106e-04
#
# Epoch 00032: val_loss improved from 0.00077 to 0.00077, saving model to best_weights.h5
# Epoch 33/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.6091e-04 - val_loss: 7.7197e-04
#
# Epoch 00033: val_loss did not improve from 0.00077
# Epoch 34/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.6235e-04 - val_loss: 7.5623e-04
#
# Epoch 00034: val_loss improved from 0.00077 to 0.00076, saving model to best_weights.h5
# Epoch 35/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.5286e-04 - val_loss: 7.9029e-04
#
# Epoch 00035: val_loss did not improve from 0.00076
# Epoch 36/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.4888e-04 - val_loss: 8.0267e-04
#
# Epoch 00036: val_loss did not improve from 0.00076
# Epoch 37/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.4188e-04 - val_loss: 7.3528e-04
#
# Epoch 00037: val_loss improved from 0.00076 to 0.00074, saving model to best_weights.h5
# Epoch 38/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.3513e-04 - val_loss: 8.2021e-04
#
# Epoch 00038: val_loss did not improve from 0.00074
# Epoch 39/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.4408e-04 - val_loss: 7.2924e-04
#
# Epoch 00039: val_loss improved from 0.00074 to 0.00073, saving model to best_weights.h5
# Epoch 40/150
# 1712/1712 [==============================] - 16s 9ms/step - loss: 2.2778e-04 - val_loss: 7.1879e-04
#
# Epoch 00040: val_loss improved from 0.00073 to 0.00072, saving model to best_weights.h5
# Epoch 41/150
# 1712/1712 [==============================] - 16s 10ms/step - loss: 2.1785e-04 - val_loss: 7.7638e-04
#
# Epoch 00041: val_loss did not improve from 0.00072
# Epoch 42/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.1691e-04 - val_loss: 7.7081e-04
#
# Epoch 00042: val_loss did not improve from 0.00072
# Epoch 43/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.1350e-04 - val_loss: 7.4301e-04
#
# Epoch 00043: val_loss did not improve from 0.00072
# Epoch 44/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.0806e-04 - val_loss: 7.8203e-04
#
# Epoch 00044: val_loss did not improve from 0.00072
# Epoch 45/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.0900e-04 - val_loss: 7.5651e-04
#
# Epoch 00045: val_loss did not improve from 0.00072
# Epoch 46/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.0860e-04 - val_loss: 7.3918e-04
#
# Epoch 00046: val_loss did not improve from 0.00072
# Epoch 47/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.0127e-04 - val_loss: 7.5195e-04
#
# Epoch 00047: val_loss did not improve from 0.00072
# Epoch 48/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.9970e-04 - val_loss: 7.2244e-04
#
# Epoch 00048: val_loss did not improve from 0.00072
# Epoch 49/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.9615e-04 - val_loss: 7.2630e-04
#
# Epoch 00049: val_loss did not improve from 0.00072
# Epoch 50/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.9644e-04 - val_loss: 7.3974e-04
#
# Epoch 00050: val_loss did not improve from 0.00072
# Epoch 51/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.9429e-04 - val_loss: 7.3655e-04
#
# Epoch 00051: val_loss did not improve from 0.00072
# Epoch 52/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.9130e-04 - val_loss: 7.7906e-04
#
# Epoch 00052: val_loss did not improve from 0.00072
# Epoch 53/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.9260e-04 - val_loss: 7.6203e-04
#
# Epoch 00053: val_loss did not improve from 0.00072
# Epoch 54/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.8689e-04 - val_loss: 7.4359e-04
#
# Epoch 00054: val_loss did not improve from 0.00072
# Epoch 55/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.8382e-04 - val_loss: 7.2345e-04
#
# Epoch 00055: val_loss did not improve from 0.00072
# Epoch 56/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.7821e-04 - val_loss: 7.3110e-04
#
# Epoch 00056: val_loss did not improve from 0.00072
# Epoch 57/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.8323e-04 - val_loss: 7.9482e-04
#
# Epoch 00057: val_loss did not improve from 0.00072
# Epoch 58/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.8230e-04 - val_loss: 7.5737e-04
#
# Epoch 00058: val_loss did not improve from 0.00072
# Epoch 59/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.8082e-04 - val_loss: 7.3864e-04
#
# Epoch 00059: val_loss did not improve from 0.00072
# Epoch 60/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.7847e-04 - val_loss: 7.4261e-04
#
# Epoch 00060: val_loss did not improve from 0.00072
# Epoch 61/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.6981e-04 - val_loss: 7.2832e-04
#
# Epoch 00061: val_loss did not improve from 0.00072
# Epoch 62/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.7237e-04 - val_loss: 7.2280e-04
#
# Epoch 00062: val_loss did not improve from 0.00072
# Epoch 63/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.6957e-04 - val_loss: 7.2699e-04
#
# Epoch 00063: val_loss did not improve from 0.00072
# Epoch 64/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.6819e-04 - val_loss: 7.5661e-04
#
# Epoch 00064: val_loss did not improve from 0.00072
# Epoch 65/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.6914e-04 - val_loss: 7.3921e-04
#
# Epoch 00065: val_loss did not improve from 0.00072
# Epoch 66/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.6172e-04 - val_loss: 7.5343e-04
#
# Epoch 00066: val_loss did not improve from 0.00072
# Epoch 67/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.6020e-04 - val_loss: 7.1472e-04
#
# Epoch 00067: val_loss improved from 0.00072 to 0.00071, saving model to best_weights.h5
# Epoch 68/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.5860e-04 - val_loss: 7.2320e-04
#
# Epoch 00068: val_loss did not improve from 0.00071
# Epoch 69/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.5779e-04 - val_loss: 7.1804e-04
#
# Epoch 00069: val_loss did not improve from 0.00071
# Epoch 70/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.5315e-04 - val_loss: 7.1231e-04
#
# Epoch 00070: val_loss improved from 0.00071 to 0.00071, saving model to best_weights.h5
# Epoch 71/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.5303e-04 - val_loss: 7.4135e-04
#
# Epoch 00071: val_loss did not improve from 0.00071
# Epoch 72/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.5373e-04 - val_loss: 7.1577e-04
#
# Epoch 00072: val_loss did not improve from 0.00071
# Epoch 73/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.5277e-04 - val_loss: 7.1946e-04
#
# Epoch 00073: val_loss did not improve from 0.00071
# Epoch 74/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.5507e-04 - val_loss: 7.4962e-04
#
# Epoch 00074: val_loss did not improve from 0.00071
# Epoch 75/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.4618e-04 - val_loss: 7.2720e-04
#
# Epoch 00075: val_loss did not improve from 0.00071
# Epoch 76/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.4627e-04 - val_loss: 7.0973e-04
#
# Epoch 00076: val_loss improved from 0.00071 to 0.00071, saving model to best_weights.h5
# Epoch 77/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.4638e-04 - val_loss: 7.4217e-04
#
# Epoch 00077: val_loss did not improve from 0.00071
# Epoch 78/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.4506e-04 - val_loss: 7.5321e-04
#
# Epoch 00078: val_loss did not improve from 0.00071
# Epoch 79/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.4408e-04 - val_loss: 7.2025e-04
#
# Epoch 00079: val_loss did not improve from 0.00071
# Epoch 80/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.4194e-04 - val_loss: 7.9110e-04
#
# Epoch 00080: val_loss did not improve from 0.00071
# Epoch 81/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.4414e-04 - val_loss: 7.3451e-04
#
# Epoch 00081: val_loss did not improve from 0.00071
# Epoch 82/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.4121e-04 - val_loss: 7.3137e-04
#
# Epoch 00082: val_loss did not improve from 0.00071
# Epoch 83/150
# 1712/1712 [==============================] - 18s 10ms/step - loss: 1.3977e-04 - val_loss: 7.1620e-04
#
# Epoch 00083: val_loss did not improve from 0.00071
# Epoch 84/150
# 1712/1712 [==============================] - 15s 9ms/step - loss: 1.3904e-04 - val_loss: 7.0994e-04
#
# Epoch 00084: val_loss did not improve from 0.00071
# Epoch 85/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3736e-04 - val_loss: 7.3839e-04
#
# Epoch 00085: val_loss did not improve from 0.00071
# Epoch 86/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3297e-04 - val_loss: 7.5486e-04
#
# Epoch 00086: val_loss did not improve from 0.00071
# Epoch 87/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3547e-04 - val_loss: 7.5929e-04
#
# Epoch 00087: val_loss did not improve from 0.00071
# Epoch 88/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3641e-04 - val_loss: 7.3773e-04
#
# Epoch 00088: val_loss did not improve from 0.00071
# Epoch 89/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3302e-04 - val_loss: 7.1237e-04
#
# Epoch 00089: val_loss did not improve from 0.00071
# Epoch 90/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2942e-04 - val_loss: 7.0148e-04
#
# Epoch 00090: val_loss improved from 0.00071 to 0.00070, saving model to best_weights.h5
# Epoch 91/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2888e-04 - val_loss: 7.3433e-04
#
# Epoch 00091: val_loss did not improve from 0.00070
# Epoch 92/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2834e-04 - val_loss: 7.4064e-04
#
# Epoch 00092: val_loss did not improve from 0.00070
# Epoch 93/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3048e-04 - val_loss: 7.3499e-04
#
# Epoch 00093: val_loss did not improve from 0.00070
# Epoch 94/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2653e-04 - val_loss: 7.2530e-04
#
# Epoch 00094: val_loss did not improve from 0.00070
# Epoch 95/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2563e-04 - val_loss: 7.4071e-04
#
# Epoch 00095: val_loss did not improve from 0.00070
# Epoch 96/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2803e-04 - val_loss: 7.2021e-04
#
# Epoch 00096: val_loss did not improve from 0.00070
# Epoch 97/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2638e-04 - val_loss: 7.1665e-04
#
# Epoch 00097: val_loss did not improve from 0.00070
# Epoch 98/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2951e-04 - val_loss: 7.0595e-04
#
# Epoch 00098: val_loss did not improve from 0.00070
# Epoch 99/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2216e-04 - val_loss: 7.5427e-04
#
# Epoch 00099: val_loss did not improve from 0.00070
# Epoch 100/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2373e-04 - val_loss: 7.4831e-04
#
# Epoch 00100: val_loss did not improve from 0.00070
# Epoch 101/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2086e-04 - val_loss: 7.3560e-04
#
# Epoch 00101: val_loss did not improve from 0.00070
# Epoch 102/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2050e-04 - val_loss: 7.7954e-04
#
# Epoch 00102: val_loss did not improve from 0.00070
# Epoch 103/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2266e-04 - val_loss: 7.6189e-04
#
# Epoch 00103: val_loss did not improve from 0.00070
# Epoch 104/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1789e-04 - val_loss: 7.6188e-04
#
# Epoch 00104: val_loss did not improve from 0.00070
# Epoch 105/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1929e-04 - val_loss: 7.4581e-04
#
# Epoch 00105: val_loss did not improve from 0.00070
# Epoch 106/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1530e-04 - val_loss: 7.5989e-04
#
# Epoch 00106: val_loss did not improve from 0.00070
# Epoch 107/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1608e-04 - val_loss: 7.4900e-04
#
# Epoch 00107: val_loss did not improve from 0.00070
# Epoch 108/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1590e-04 - val_loss: 7.5954e-04
#
# Epoch 00108: val_loss did not improve from 0.00070
# Epoch 109/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1573e-04 - val_loss: 7.6886e-04
#
# Epoch 00109: val_loss did not improve from 0.00070
# Epoch 110/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1573e-04 - val_loss: 7.3103e-04
#
# Epoch 00110: val_loss did not improve from 0.00070
# Epoch 111/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2153e-04 - val_loss: 7.4208e-04
#
# Epoch 00111: val_loss did not improve from 0.00070
# Epoch 112/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1907e-04 - val_loss: 7.3185e-04
#
# Epoch 00112: val_loss did not improve from 0.00070
# Epoch 113/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1304e-04 - val_loss: 7.4493e-04
#
# Epoch 00113: val_loss did not improve from 0.00070
# Epoch 114/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1294e-04 - val_loss: 7.0845e-04
#
# Epoch 00114: val_loss did not improve from 0.00070
# Epoch 115/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1181e-04 - val_loss: 7.1517e-04
#
# Epoch 00115: val_loss did not improve from 0.00070
# Epoch 116/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1661e-04 - val_loss: 7.3165e-04
#
# Epoch 00116: val_loss did not improve from 0.00070
# Epoch 117/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0867e-04 - val_loss: 7.7927e-04
#
# Epoch 00117: val_loss did not improve from 0.00070
# Epoch 118/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0851e-04 - val_loss: 7.5802e-04
#
# Epoch 00118: val_loss did not improve from 0.00070
# Epoch 119/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0662e-04 - val_loss: 7.3800e-04
#
# Epoch 00119: val_loss did not improve from 0.00070
# Epoch 120/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0454e-04 - val_loss: 7.5055e-04
#
# Epoch 00120: val_loss did not improve from 0.00070
# Epoch 121/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0362e-04 - val_loss: 7.2434e-04
#
# Epoch 00121: val_loss did not improve from 0.00070
# Epoch 122/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0552e-04 - val_loss: 7.1932e-04
#
# Epoch 00122: val_loss did not improve from 0.00070
# Epoch 123/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0768e-04 - val_loss: 7.3470e-04
#
# Epoch 00123: val_loss did not improve from 0.00070
# Epoch 124/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0619e-04 - val_loss: 7.4174e-04
#
# Epoch 00124: val_loss did not improve from 0.00070
# Epoch 125/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0414e-04 - val_loss: 7.6716e-04
#
# Epoch 00125: val_loss did not improve from 0.00070
# Epoch 126/150
# 1712/1712 [==============================] - 18s 10ms/step - loss: 1.0310e-04 - val_loss: 7.4724e-04
#
# Epoch 00126: val_loss did not improve from 0.00070
# Epoch 127/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0076e-04 - val_loss: 7.5957e-04
#
# Epoch 00127: val_loss did not improve from 0.00070
# Epoch 128/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0059e-04 - val_loss: 7.7039e-04
#
# Epoch 00128: val_loss did not improve from 0.00070
# Epoch 129/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0190e-04 - val_loss: 7.4829e-04
#
# Epoch 00129: val_loss did not improve from 0.00070
# Epoch 130/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0217e-04 - val_loss: 7.4067e-04
#
# Epoch 00130: val_loss did not improve from 0.00070
# Epoch 131/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0432e-04 - val_loss: 7.5187e-04
#
# Epoch 00131: val_loss did not improve from 0.00070
# Epoch 132/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.5623e-05 - val_loss: 7.4411e-04
#
# Epoch 00132: val_loss did not improve from 0.00070
# Epoch 133/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.5100e-05 - val_loss: 7.4031e-04
#
# Epoch 00133: val_loss did not improve from 0.00070
# Epoch 134/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.5574e-05 - val_loss: 7.4986e-04
#
# Epoch 00134: val_loss did not improve from 0.00070
# Epoch 135/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.6010e-05 - val_loss: 7.3305e-04
#
# Epoch 00135: val_loss did not improve from 0.00070
# Epoch 136/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.8809e-05 - val_loss: 7.5762e-04
#
# Epoch 00136: val_loss did not improve from 0.00070
# Epoch 137/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.9749e-05 - val_loss: 7.3465e-04
#
# Epoch 00137: val_loss did not improve from 0.00070
# Epoch 138/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.6854e-05 - val_loss: 7.9025e-04
#
# Epoch 00138: val_loss did not improve from 0.00070
# Epoch 139/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.5822e-05 - val_loss: 7.3926e-04
#
# Epoch 00139: val_loss did not improve from 0.00070
# Epoch 140/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.5112e-05 - val_loss: 7.4363e-04
#
# Epoch 00140: val_loss did not improve from 0.00070
# Epoch 141/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.5106e-05 - val_loss: 7.3214e-04
#
# Epoch 00141: val_loss did not improve from 0.00070
# Epoch 142/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.2855e-05 - val_loss: 7.5492e-04
#
# Epoch 00142: val_loss did not improve from 0.00070
# Epoch 143/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.2488e-05 - val_loss: 7.4450e-04
#
# Epoch 00143: val_loss did not improve from 0.00070
# Epoch 144/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.1054e-05 - val_loss: 7.4479e-04
#
# Epoch 00144: val_loss did not improve from 0.00070
# Epoch 145/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.1942e-05 - val_loss: 7.4936e-04
#
# Epoch 00145: val_loss did not improve from 0.00070
# Epoch 146/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.2434e-05 - val_loss: 7.5398e-04
#
# Epoch 00146: val_loss did not improve from 0.00070
# Epoch 147/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.4638e-05 - val_loss: 7.3442e-04
#
# Epoch 00147: val_loss did not improve from 0.00070
# Epoch 148/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.1706e-05 - val_loss: 7.6479e-04
#
# Epoch 00148: val_loss did not improve from 0.00070
# Epoch 149/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.1432e-05 - val_loss: 7.2865e-04
#
# Epoch 00149: val_loss did not improve from 0.00070
# Epoch 150/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 8.6490e-05 - val_loss: 7.5311e-04
#
# Epoch 00150: val_loss did not improve from 0.00070

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# ### 觀察 model 在 testing 上的結果

# %%
# 讀取測試資料集
imgs_test, _ = load_data(dirname = 'test.csv')

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %% [markdown]
# 目前為止，大致可以觀察到，直接使用簡單的模型以及訓練方式在這組數據上應該可以在訓練集和測試集上都得到一個還不錯的結果，說明這組資料其實不會很難。

# %%
model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')

# %%
# Your code
# 實現圖片以及關機點 label 做左右翻轉的函數
def augment_data(img, points):
    rows, cols = img.shape
    new_img = np.copy(img)
    
    # 翻轉圖片
    for i in range(96):
        for j in range(48):
            temp = img[i][j]
            new_img[i][j] = img[i][cols-j-1]
            new_img[i][cols-j-1] = temp
            
    # 翻轉關鍵點 label
    new_points = np.copy(points)
    for i in range(0, 30, 2):
        new_points[i] = -points[i]
    
    # 調整對稱的 label
    new_points_temp = np.copy(new_points)
    new_points[0:2] = new_points_temp[2:4]
    new_points[2:4] = new_points_temp[0:2]
    new_points[4:6] = new_points_temp[8:10]
    new_points[6:8] = new_points_temp[10:12]
    new_points[8:10] = new_points_temp[4:6]
    new_points[10:12] = new_points_temp[6:8]
    new_points[12:14] = new_points_temp[16:18]
    new_points[14:16] = new_points_temp[18:20]
    new_points[16:18] = new_points_temp[12:14]
    new_points[18:20] = new_points_temp[14:16]
    new_points[22:24] = new_points_temp[24:26]
    new_points[24:26] = new_points_temp[22:24]
        
    return new_img, new_points

# %%
flip_img, flip_points = augment_data(imgs_train[0], points_train[0])
fig = plt.figure()

ax = fig.add_subplot(1, 2, 1, xticks=[], yticks=[])
plot_keypoints(imgs_train[0], points_train[0]) # 原來的圖片

ax = fig.add_subplot(1, 2, 2, xticks=[], yticks=[])
plot_keypoints(flip_img, flip_points) # 翻轉後的圖片

# %%
# 創建 list
aug_imgs_train = []
aug_points_train = []

# 對所有原始資料做 augmentation
for i in range(imgs_train.shape[0]):
    # 做左右翻轉
    aug_img, aug_point = augment_data(imgs_train[i], points_train[i])
    
    # append 原始資料
    aug_imgs_train.append(imgs_train[i])
    aug_points_train.append(points_train[i]) 
    
    # append 做過 augmentation 後的資料
    aug_imgs_train.append(aug_img)
    aug_points_train.append(aug_point) 

# convert to numpy
aug_imgs_train = np.array(aug_imgs_train)   
aug_points_train = np.copy(aug_points_train)

print(aug_imgs_train.shape)
print(aug_points_train.shape)
# Out:
# (4280, 96, 96)
# (4280, 30)

# %%
# model checkpoint 
checkpoint_aug = ModelCheckpoint('best_weights_augment.h5', verbose=1, save_best_only=True)
# training the model
hist_model_aug = model_with_augment.fit(aug_imgs_train.reshape(aug_imgs_train.shape[0], 96, 96, 1), aug_points_train, 
                                        validation_split=0.2, batch_size=64, callbacks=[checkpoint_aug, hist], 
                                        shuffle=True, epochs=150, verbose=1)
# Out:
# Train on 3424 samples, validate on 856 samples
# Epoch 1/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 0.0034 - val_loss: 0.0021
#
# Epoch 00001: val_loss improved from inf to 0.00209, saving model to best_weights_augment.h5
# Epoch 2/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 0.0012 - val_loss: 0.0018
#
# Epoch 00002: val_loss improved from 0.00209 to 0.00181, saving model to best_weights_augment.h5
# Epoch 3/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.5973e-04 - val_loss: 0.0016
#
# Epoch 00003: val_loss improved from 0.00181 to 0.00164, saving model to best_weights_augment.h5
# Epoch 4/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 7.2594e-04 - val_loss: 0.0012
#
# Epoch 00004: val_loss improved from 0.00164 to 0.00123, saving model to best_weights_augment.h5
# Epoch 5/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 5.8593e-04 - val_loss: 0.0011
#
# Epoch 00005: val_loss improved from 0.00123 to 0.00113, saving model to best_weights_augment.h5
# Epoch 6/150
# 3424/3424 [==============================] - 32s 9ms/step - loss: 4.9962e-04 - val_loss: 0.0010
#
# Epoch 00006: val_loss improved from 0.00113 to 0.00103, saving model to best_weights_augment.h5
# Epoch 7/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 4.4444e-04 - val_loss: 9.4837e-04
#
# Epoch 00007: val_loss improved from 0.00103 to 0.00095, saving model to best_weights_augment.h5
# Epoch 8/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 4.1905e-04 - val_loss: 8.9990e-04
#
# Epoch 00008: val_loss improved from 0.00095 to 0.00090, saving model to best_weights_augment.h5
# Epoch 9/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 3.7106e-04 - val_loss: 8.9359e-04
#
# Epoch 00009: val_loss improved from 0.00090 to 0.00089, saving model to best_weights_augment.h5
# Epoch 10/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 3.5253e-04 - val_loss: 8.2870e-04
#
# Epoch 00010: val_loss improved from 0.00089 to 0.00083, saving model to best_weights_augment.h5
# Epoch 11/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 3.3088e-04 - val_loss: 8.3881e-04
#
# Epoch 00011: val_loss did not improve from 0.00083
# Epoch 12/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 3.1283e-04 - val_loss: 8.9267e-04
#
# Epoch 00012: val_loss did not improve from 0.00083
# Epoch 13/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 3.1035e-04 - val_loss: 8.0397e-04
#
# Epoch 00013: val_loss improved from 0.00083 to 0.00080, saving model to best_weights_augment.h5
# Epoch 14/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 2.9372e-04 - val_loss: 8.0754e-04
#
# Epoch 00014: val_loss did not improve from 0.00080
# Epoch 15/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 2.7729e-04 - val_loss: 7.9100e-04
#
# Epoch 00015: val_loss improved from 0.00080 to 0.00079, saving model to best_weights_augment.h5
# Epoch 16/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 2.6671e-04 - val_loss: 7.8074e-04
#
# Epoch 00016: val_loss improved from 0.00079 to 0.00078, saving model to best_weights_augment.h5
# Epoch 17/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 2.5500e-04 - val_loss: 7.4343e-04
#
# Epoch 00017: val_loss improved from 0.00078 to 0.00074, saving model to best_weights_augment.h5
# Epoch 18/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 2.4892e-04 - val_loss: 7.4736e-04
#
# Epoch 00018: val_loss did not improve from 0.00074
# Epoch 19/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 2.3763e-04 - val_loss: 7.3607e-04
#
# Epoch 00019: val_loss improved from 0.00074 to 0.00074, saving model to best_weights_augment.h5
# Epoch 20/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 2.3729e-04 - val_loss: 7.0461e-04
#
# Epoch 00020: val_loss improved from 0.00074 to 0.00070, saving model to best_weights_augment.h5
# Epoch 21/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 2.2802e-04 - val_loss: 7.2925e-04
#
# Epoch 00021: val_loss did not improve from 0.00070
# Epoch 22/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 2.2048e-04 - val_loss: 7.0566e-04
#
# Epoch 00022: val_loss did not improve from 0.00070
# Epoch 23/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 2.1845e-04 - val_loss: 7.1249e-04
#
# Epoch 00023: val_loss did not improve from 0.00070
# Epoch 24/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 2.0864e-04 - val_loss: 6.9534e-04
#
# Epoch 00024: val_loss improved from 0.00070 to 0.00070, saving model to best_weights_augment.h5
# Epoch 25/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 2.0664e-04 - val_loss: 7.0987e-04
#
# Epoch 00025: val_loss did not improve from 0.00070
# Epoch 26/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 2.0067e-04 - val_loss: 6.6380e-04
#
# Epoch 00026: val_loss improved from 0.00070 to 0.00066, saving model to best_weights_augment.h5
# Epoch 27/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.9395e-04 - val_loss: 6.8966e-04
#
# Epoch 00027: val_loss did not improve from 0.00066
# Epoch 28/150
# 3424/3424 [==============================] - 32s 9ms/step - loss: 1.9289e-04 - val_loss: 6.9784e-04
#
# Epoch 00028: val_loss did not improve from 0.00066
# Epoch 29/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.8773e-04 - val_loss: 6.8127e-04
#
# Epoch 00029: val_loss did not improve from 0.00066
# Epoch 30/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.8712e-04 - val_loss: 6.6980e-04
#
# Epoch 00030: val_loss did not improve from 0.00066
# Epoch 31/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.8163e-04 - val_loss: 6.8981e-04
#
# Epoch 00031: val_loss did not improve from 0.00066
# Epoch 32/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.7785e-04 - val_loss: 6.8416e-04
#
# Epoch 00032: val_loss did not improve from 0.00066
# Epoch 33/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.7433e-04 - val_loss: 7.0608e-04
#
# Epoch 00033: val_loss did not improve from 0.00066
# Epoch 34/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.7131e-04 - val_loss: 6.8127e-04
#
# Epoch 00034: val_loss did not improve from 0.00066
# Epoch 35/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.6941e-04 - val_loss: 7.0127e-04
#
# Epoch 00035: val_loss did not improve from 0.00066
# Epoch 36/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.6415e-04 - val_loss: 7.0096e-04
#
# Epoch 00036: val_loss did not improve from 0.00066
# Epoch 37/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.5954e-04 - val_loss: 7.3550e-04
#
# Epoch 00037: val_loss did not improve from 0.00066
# Epoch 38/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.6098e-04 - val_loss: 6.7634e-04
#
# Epoch 00038: val_loss did not improve from 0.00066
# Epoch 39/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.5361e-04 - val_loss: 6.8855e-04
#
# Epoch 00039: val_loss did not improve from 0.00066
# Epoch 40/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.5368e-04 - val_loss: 6.8790e-04
#
# Epoch 00040: val_loss did not improve from 0.00066
# Epoch 41/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.5249e-04 - val_loss: 6.6313e-04
#
# Epoch 00041: val_loss improved from 0.00066 to 0.00066, saving model to best_weights_augment.h5
# Epoch 42/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.4900e-04 - val_loss: 6.6876e-04
#
# Epoch 00042: val_loss did not improve from 0.00066
# Epoch 43/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.4658e-04 - val_loss: 6.8112e-04
#
# Epoch 00043: val_loss did not improve from 0.00066
# Epoch 44/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.4575e-04 - val_loss: 6.7578e-04
#
# Epoch 00044: val_loss did not improve from 0.00066
# Epoch 45/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.4473e-04 - val_loss: 6.9391e-04
#
# Epoch 00045: val_loss did not improve from 0.00066
# Epoch 46/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.4180e-04 - val_loss: 6.8386e-04
#
# Epoch 00046: val_loss did not improve from 0.00066
# Epoch 47/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.4010e-04 - val_loss: 6.7765e-04
#
# Epoch 00047: val_loss did not improve from 0.00066
# Epoch 48/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.3696e-04 - val_loss: 7.2350e-04
#
# Epoch 00048: val_loss did not improve from 0.00066
# Epoch 49/150
# 3424/3424 [==============================] - 31s 9ms/step - loss: 1.3937e-04 - val_loss: 6.6663e-04
#
# Epoch 00049: val_loss did not improve from 0.00066
# Epoch 50/150
# 3424/3424 [==============================] - 29s 8ms/step - loss: 1.3783e-04 - val_loss: 6.6648e-04
#
# Epoch 00050: val_loss did not improve from 0.00066
# Epoch 51/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.3332e-04 - val_loss: 6.8242e-04
#
# Epoch 00051: val_loss did not improve from 0.00066
# Epoch 52/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.2788e-04 - val_loss: 7.0242e-04
#
# Epoch 00052: val_loss did not improve from 0.00066
# Epoch 53/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.2963e-04 - val_loss: 7.0494e-04
#
# Epoch 00053: val_loss did not improve from 0.00066
# Epoch 54/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.3037e-04 - val_loss: 7.1409e-04
#
# Epoch 00054: val_loss did not improve from 0.00066
# Epoch 55/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.2803e-04 - val_loss: 6.8752e-04
#
# Epoch 00055: val_loss did not improve from 0.00066
# Epoch 56/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.2639e-04 - val_loss: 7.2534e-04
#
# Epoch 00056: val_loss did not improve from 0.00066
# Epoch 57/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.2238e-04 - val_loss: 6.9058e-04
#
# Epoch 00057: val_loss did not improve from 0.00066
# Epoch 58/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.2077e-04 - val_loss: 6.9092e-04
#
# Epoch 00058: val_loss did not improve from 0.00066
# Epoch 59/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.2017e-04 - val_loss: 7.2778e-04
#
# Epoch 00059: val_loss did not improve from 0.00066
# Epoch 60/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.1963e-04 - val_loss: 6.8394e-04
#
# Epoch 00060: val_loss did not improve from 0.00066
# Epoch 61/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.1824e-04 - val_loss: 6.6243e-04
#
# Epoch 00061: val_loss improved from 0.00066 to 0.00066, saving model to best_weights_augment.h5
# Epoch 62/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.1721e-04 - val_loss: 6.5821e-04
#
# Epoch 00062: val_loss improved from 0.00066 to 0.00066, saving model to best_weights_augment.h5
# Epoch 63/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.1644e-04 - val_loss: 6.7327e-04
#
# Epoch 00063: val_loss did not improve from 0.00066
# Epoch 64/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.1321e-04 - val_loss: 6.7933e-04
#
# Epoch 00064: val_loss did not improve from 0.00066
# Epoch 65/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.1199e-04 - val_loss: 7.1392e-04
#
# Epoch 00065: val_loss did not improve from 0.00066
# Epoch 66/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.1335e-04 - val_loss: 6.6079e-04
#
# Epoch 00066: val_loss did not improve from 0.00066
# Epoch 67/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.1190e-04 - val_loss: 7.0253e-04
#
# Epoch 00067: val_loss did not improve from 0.00066
# Epoch 68/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.1141e-04 - val_loss: 6.6896e-04
#
# Epoch 00068: val_loss did not improve from 0.00066
# Epoch 69/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.1011e-04 - val_loss: 6.6497e-04
#
# Epoch 00069: val_loss did not improve from 0.00066
# Epoch 70/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.0931e-04 - val_loss: 6.9321e-04
#
# Epoch 00070: val_loss did not improve from 0.00066
# Epoch 71/150
# 3424/3424 [==============================] - 32s 9ms/step - loss: 1.0635e-04 - val_loss: 6.7943e-04
#
# Epoch 00071: val_loss did not improve from 0.00066
# Epoch 72/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.0564e-04 - val_loss: 6.7077e-04
#
# Epoch 00072: val_loss did not improve from 0.00066
# Epoch 73/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.0596e-04 - val_loss: 6.7175e-04
#
# Epoch 00073: val_loss did not improve from 0.00066
# Epoch 74/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.0360e-04 - val_loss: 6.6636e-04
#
# Epoch 00074: val_loss did not improve from 0.00066
# Epoch 75/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.0372e-04 - val_loss: 7.0205e-04
#
# Epoch 00075: val_loss did not improve from 0.00066
# Epoch 76/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.0313e-04 - val_loss: 6.8253e-04
#
# Epoch 00076: val_loss did not improve from 0.00066
# Epoch 77/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.0247e-04 - val_loss: 6.5098e-04
#
# Epoch 00077: val_loss improved from 0.00066 to 0.00065, saving model to best_weights_augment.h5
# Epoch 78/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.0400e-04 - val_loss: 6.6933e-04
#
# Epoch 00078: val_loss did not improve from 0.00065
# Epoch 79/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1.0251e-04 - val_loss: 7.0176e-04
#
# Epoch 00079: val_loss did not improve from 0.00065
# Epoch 80/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.9035e-05 - val_loss: 6.8411e-04
#
# Epoch 00080: val_loss did not improve from 0.00065
# Epoch 81/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.9481e-05 - val_loss: 6.6344e-04
#
# Epoch 00081: val_loss did not improve from 0.00065
# Epoch 82/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.9241e-05 - val_loss: 6.6309e-04
#
# Epoch 00082: val_loss did not improve from 0.00065
# Epoch 83/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.5538e-05 - val_loss: 6.7211e-04
#
# Epoch 00083: val_loss did not improve from 0.00065
# Epoch 84/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.6452e-05 - val_loss: 7.0308e-04
#
# Epoch 00084: val_loss did not improve from 0.00065
# Epoch 85/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.7344e-05 - val_loss: 6.5752e-04
#
# Epoch 00085: val_loss did not improve from 0.00065
# Epoch 86/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.7606e-05 - val_loss: 6.7295e-04
#
# Epoch 00086: val_loss did not improve from 0.00065
# Epoch 87/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.5634e-05 - val_loss: 6.6004e-04
#
# Epoch 00087: val_loss did not improve from 0.00065
# Epoch 88/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.3278e-05 - val_loss: 7.0460e-04
#
# Epoch 00088: val_loss did not improve from 0.00065
# Epoch 89/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.6211e-05 - val_loss: 6.6525e-04
#
# Epoch 00089: val_loss did not improve from 0.00065
# Epoch 90/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.3324e-05 - val_loss: 6.7406e-04
#
# Epoch 00090: val_loss did not improve from 0.00065
# Epoch 91/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.2118e-05 - val_loss: 6.7530e-04
#
# Epoch 00091: val_loss did not improve from 0.00065
# Epoch 92/150
# 3424/3424 [==============================] - 29s 9ms/step - loss: 9.1045e-05 - val_loss: 6.6753e-04
#
# Epoch 00092: val_loss did not improve from 0.00065
# Epoch 93/150
# 3424/3424 [==============================] - 30s 9ms/step - loss: 9.3026e-05 - val_loss: 7.1047e-04
#
# Epoch 00093: val_loss did not improve from 0.00065
# Epoch 94/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.2443e-05 - val_loss: 6.6498e-04
#
# Epoch 00094: val_loss did not improve from 0.00065
# Epoch 95/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.2335e-05 - val_loss: 6.9036e-04
#
# Epoch 00095: val_loss did not improve from 0.00065
# Epoch 96/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.0582e-05 - val_loss: 6.7297e-04
#
# Epoch 00096: val_loss did not improve from 0.00065
# Epoch 97/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.9164e-05 - val_loss: 6.6368e-04
#
# Epoch 00097: val_loss did not improve from 0.00065
# Epoch 98/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.9487e-05 - val_loss: 6.7700e-04
#
# Epoch 00098: val_loss did not improve from 0.00065
# Epoch 99/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.9098e-05 - val_loss: 6.7992e-04
#
# Epoch 00099: val_loss did not improve from 0.00065
# Epoch 100/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.7910e-05 - val_loss: 6.5671e-04
#
# Epoch 00100: val_loss did not improve from 0.00065
# Epoch 101/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.8874e-05 - val_loss: 6.7297e-04
#
# Epoch 00101: val_loss did not improve from 0.00065
# Epoch 102/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.1539e-05 - val_loss: 6.9113e-04
#
# Epoch 00102: val_loss did not improve from 0.00065
# Epoch 103/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.5469e-05 - val_loss: 6.5433e-04
#
# Epoch 00103: val_loss did not improve from 0.00065
# Epoch 104/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.9079e-05 - val_loss: 6.6083e-04
#
# Epoch 00104: val_loss did not improve from 0.00065
# Epoch 105/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.6373e-05 - val_loss: 6.6668e-04
#
# Epoch 00105: val_loss did not improve from 0.00065
# Epoch 106/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.9075e-05 - val_loss: 6.8363e-04
#
# Epoch 00106: val_loss did not improve from 0.00065
# Epoch 107/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.6699e-05 - val_loss: 6.7087e-04
#
# Epoch 00107: val_loss did not improve from 0.00065
# Epoch 108/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.5657e-05 - val_loss: 6.7116e-04
#
# Epoch 00108: val_loss did not improve from 0.00065
# Epoch 109/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.4977e-05 - val_loss: 6.6989e-04
#
# Epoch 00109: val_loss did not improve from 0.00065
# Epoch 110/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.5587e-05 - val_loss: 6.6005e-04
#
# Epoch 00110: val_loss did not improve from 0.00065
# Epoch 111/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.6475e-05 - val_loss: 6.8963e-04
#
# Epoch 00111: val_loss did not improve from 0.00065
# Epoch 112/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.7521e-05 - val_loss: 6.7391e-04
#
# Epoch 00112: val_loss did not improve from 0.00065
# Epoch 113/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.5375e-05 - val_loss: 6.5948e-04
#
# Epoch 00113: val_loss did not improve from 0.00065
# Epoch 114/150
# 3424/3424 [==============================] - 32s 9ms/step - loss: 8.5270e-05 - val_loss: 6.7322e-04
#
# Epoch 00114: val_loss did not improve from 0.00065
# Epoch 115/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.2937e-05 - val_loss: 6.7356e-04
#
# Epoch 00115: val_loss did not improve from 0.00065
# Epoch 116/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.3722e-05 - val_loss: 6.8574e-04
#
# Epoch 00116: val_loss did not improve from 0.00065
# Epoch 117/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.3780e-05 - val_loss: 7.0210e-04
#
# Epoch 00117: val_loss did not improve from 0.00065
# Epoch 118/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.8798e-05 - val_loss: 6.7491e-04
#
# Epoch 00118: val_loss did not improve from 0.00065
# Epoch 119/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.8613e-05 - val_loss: 6.7013e-04
#
# Epoch 00119: val_loss did not improve from 0.00065
# Epoch 120/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.4368e-05 - val_loss: 6.4480e-04
#
# Epoch 00120: val_loss improved from 0.00065 to 0.00064, saving model to best_weights_augment.h5
# Epoch 121/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.1092e-05 - val_loss: 6.7113e-04
#
# Epoch 00121: val_loss did not improve from 0.00064
# Epoch 122/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.1781e-05 - val_loss: 6.6321e-04
#
# Epoch 00122: val_loss did not improve from 0.00064
# Epoch 123/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.1867e-05 - val_loss: 6.5315e-04
#
# Epoch 00123: val_loss did not improve from 0.00064
# Epoch 124/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.1225e-05 - val_loss: 6.6475e-04
#
# Epoch 00124: val_loss did not improve from 0.00064
# Epoch 125/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 7.9499e-05 - val_loss: 6.5186e-04
#
# Epoch 00125: val_loss did not improve from 0.00064
# Epoch 126/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.0645e-05 - val_loss: 6.8427e-04
#
# Epoch 00126: val_loss did not improve from 0.00064
# Epoch 127/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 7.9949e-05 - val_loss: 6.6276e-04
#
# Epoch 00127: val_loss did not improve from 0.00064
# Epoch 128/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 7.8094e-05 - val_loss: 6.6635e-04
#
# Epoch 00128: val_loss did not improve from 0.00064
# Epoch 129/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 7.9708e-05 - val_loss: 6.6115e-04
#
# Epoch 00129: val_loss did not improve from 0.00064
# Epoch 130/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.2053e-05 - val_loss: 6.3889e-04
#
# Epoch 00130: val_loss improved from 0.00064 to 0.00064, saving model to best_weights_augment.h5
# Epoch 131/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.1124e-05 - val_loss: 6.7940e-04
#
# Epoch 00131: val_loss did not improve from 0.00064
# Epoch 132/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 7.9666e-05 - val_loss: 6.6285e-04
#
# Epoch 00132: val_loss did not improve from 0.00064
# Epoch 133/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 7.8585e-05 - val_loss: 6.6658e-04
#
# Epoch 00133: val_loss did not improve from 0.00064
# Epoch 134/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 7.9508e-05 - val_loss: 6.6723e-04
#
# Epoch 00134: val_loss did not improve from 0.00064
# Epoch 135/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 7.8461e-05 - val_loss: 6.8341e-04
#
# Epoch 00135: val_loss did not improve from 0.00064
# Epoch 136/150
# 3424/3424 [==============================] - 32s 9ms/step - loss: 7.8987e-05 - val_loss: 6.7365e-04
#
# Epoch 00136: val_loss did not improve from 0.00064
# Epoch 137/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 7.7929e-05 - val_loss: 6.8295e-04
#
# Epoch 00137: val_loss did not improve from 0.00064
# Epoch 138/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 7.7506e-05 - val_loss: 6.7852e-04
#
# Epoch 00138: val_loss did not improve from 0.00064
# Epoch 139/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 7.7971e-05 - val_loss: 6.6442e-04
#
# Epoch 00139: val_loss did not improve from 0.00064
# Epoch 140/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 7.5722e-05 - val_loss: 6.7048e-04
#
# Epoch 00140: val_loss did not improve from 0.00064
# Epoch 141/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 7.6121e-05 - val_loss: 7.0188e-04
#
# Epoch 00141: val_loss did not improve from 0.00064
# Epoch 142/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 7.9218e-05 - val_loss: 6.7581e-04
#
# Epoch 00142: val_loss did not improve from 0.00064
# Epoch 143/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 7.7104e-05 - val_loss: 6.7429e-04
#
# Epoch 00143: val_loss did not improve from 0.00064
# Epoch 144/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 7.7476e-05 - val_loss: 6.7920e-04
#
# Epoch 00144: val_loss did not improve from 0.00064
# Epoch 145/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 7.6223e-05 - val_loss: 6.6777e-04
#
# Epoch 00145: val_loss did not improve from 0.00064
# Epoch 146/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 7.7243e-05 - val_loss: 6.6626e-04
#
# Epoch 00146: val_loss did not improve from 0.00064
# Epoch 147/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 7.5756e-05 - val_loss: 6.6753e-04
#
# Epoch 00147: val_loss did not improve from 0.00064
# Epoch 148/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 7.5919e-05 - val_loss: 6.5932e-04
#
# Epoch 00148: val_loss did not improve from 0.00064
# Epoch 149/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 7.8131e-05 - val_loss: 6.9381e-04
#
# Epoch 00149: val_loss did not improve from 0.00064
# Epoch 150/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 7.7270e-05 - val_loss: 6.6455e-04
#
# Epoch 00150: val_loss did not improve from 0.00064

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model_aug.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model_aug.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')
